# %% [markdown]
# # Resultados Prova Matemática 9.º Ano

# %%
import pandas as pd
tabela = pd.read_excel("92.xlsx")
display(tabela)
# Out:
#      Sala    Nº &BI                        Nome  Presença  Pontos  Nível  \
# 0     161  15968442     AFONSO CASTELHANO PEDRO  Realizou      44      2
# 1     161  31457110       AFONSO COSTA FAUSTINO  Realizou      31      2
# 2     161  30131737     AFONSO FERREIRA MACHADO  Realizou      65      3
# 3     161  31453244     AFONSO FIGUEIREDO LOPES  Realizou      30      2
# 4     161  15442534        AFONSO MARQUÊS GRAÇA  Realizou      50      3
# ..    ...       ...                         ...       ...     ...    ...
# 151   351  30789265  TOMÁS VENCESLAU DOS SANTOS  Realizou      35      2
# 152   351  31537772     VASCO RIBEIRO FERNANDES  Realizou      42      2
# 153   351  15900585            VICTORIA YEREMUK  Realizou      28      2
# 154   351  42240110                 VLAD BOLEAC  Realizou      56      3
# 155   351  15413226     YOLANDA MARTINS VICENTE  Realizou      77      4
#
#     Tipo Aluno  Nº Conv Turma
# 0      Interno        1   NaN
# ...

# %% [markdown]
# ## Análise Estatística

# %%
tabela[["Pontos", "Nível"]].describe()
# Out:
#            Pontos       Nível
# count  156.000000  156.000000
# mean    48.596154    2.641026
# std     23.309912    0.976820
# min      0.000000    1.000000
# 25%     30.000000    2.000000
# 50%     46.500000    2.000000
# 75%     65.250000    3.000000
# max     99.000000    5.000000

# %% [markdown]
# ## Trinta melhores alunos

# %%
tabela2 = tabela[["Nome", "Pontos", "Nível", "Turma"]]
tabela2.sort_values(by=['Pontos', 'Nível'], ascending=False).head(30)
# Out:
#                               Nome  Pontos  Nível Turma
# 77        JOSÉ MARIA LUÍS FERREIRA      99      5     A
# 79             LAURA PENAS MARTINS      95      5     B
# 15         ARIANA FERREIRA MACHADO      94      5     A
# 32        CATARINA FERREIRA FILIPE      93      5   NaN
# 49            FLORA LOPES FERREIRA      93      5   NaN
# 119          MIGUEL MARQUES SUSANO      92      5     A
# 23                BIA RUFINO DINIS      91      5     B
# 18             BEATRIZ INÁCIO CRUZ      89      4   NaN
# 44            DINIS LOURENÇO COSTA      88      4     A
# 48         FABIANA MARTINS VICENTE      88      4     A
# 69             JACINTA SIMÕES BELO      88      4     A
# 27   CARINA DÁLIA RAMALHO FERREIRA      86      4   NaN
# 43        DINIS JOSÉ TOMÁS MOREIRA      86      4     A
# 9    ANA BENEDITA VINAGRE MAURÍCIO      85      4     A
# 11                    ANDRÉ HOLBAN      82      4   NaN
# 62              INÊS JORGE MORGADO      82      4   NaN
# ...

# %% [markdown]
# ## 9.º A

# %%
turma_A = tabela.loc[tabela["Turma"] == "A", ["Nome", "Pontos", "Nível"]]
display(turma_A)
# Out:
#                                   Nome  Pontos  Nível
# 9        ANA BENEDITA VINAGRE MAURÍCIO      85      4
# 14   ANTHONY ISTANLLEY FERNANDES SOUZA       5      1
# 15             ARIANA FERREIRA MACHADO      94      5
# 20               BEATRIZ TAVARES SILVA      29      2
# 30         CAROLINA DOS SANTOS DELGADO      67      3
# 34        CECÍLIA BELO GALINHA HONÓRIO      63      3
# 36       CELINA PAULA MARTINS DOMINGOS      75      4
# 43            DINIS JOSÉ TOMÁS MOREIRA      86      4
# 44                DINIS LOURENÇO COSTA      88      4
# 48             FABIANA MARTINS VICENTE      88      4
# 54        GONÇALO FILIPE LUÍS TEIXEIRA      51      3
# 58              INÊS DE ALMEIDA SANTOS      51      3
# 59                 INÊS AMÉRICO DUARTE      76      4
# 60          INÊS CRISTINA DIAS ROSÁRIO      57      3
# 65        IRÍS GERARDO CORREIA MORGADO      61      3
# 66             ÍRIS SOFIA DIAS ROSÁRIO      51      3
# ...

# %% [markdown]
# ## Análise Estatística 9.º A

# %%
turma_A[["Pontos", "Nível"]].describe()
# Out:
#           Pontos      Nível
# count  29.000000  29.000000
# mean   65.689655   3.344828
# std    22.268016   0.973795
# min     5.000000   1.000000
# 25%    51.000000   3.000000
# 50%    67.000000   3.000000
# 75%    85.000000   4.000000
# max    99.000000   5.000000

# %% [markdown]
# ## 9.º A - Lista Ordenada por Pontos

# %%
turma_A = tabela.loc[tabela["Turma"] == "A", ["Nome", "Pontos", "Nível"]]
turma_A.sort_values(by=['Pontos', 'Nível'], ascending=False).head(29)
# Out:
#                                   Nome  Pontos  Nível
# 77            JOSÉ MARIA LUÍS FERREIRA      99      5
# 15             ARIANA FERREIRA MACHADO      94      5
# 119              MIGUEL MARQUES SUSANO      92      5
# 44                DINIS LOURENÇO COSTA      88      4
# 48             FABIANA MARTINS VICENTE      88      4
# 69                 JACINTA SIMÕES BELO      88      4
# 43            DINIS JOSÉ TOMÁS MOREIRA      86      4
# 9        ANA BENEDITA VINAGRE MAURÍCIO      85      4
# 139             SOFIA FERREIRA RIBEIRO      81      4
# 93          MARGARIDA FIALHO HENRIQUES      78      4
# 155            YOLANDA MARTINS VICENTE      77      4
# 59                 INÊS AMÉRICO DUARTE      76      4
# 36       CELINA PAULA MARTINS DOMINGOS      75      4
# 30         CAROLINA DOS SANTOS DELGADO      67      3
# 80            LAVÍNIA FERREIRA MARQUES      67      3
# 34        CECÍLIA BELO GALINHA HONÓRIO      63      3
# ...

# %% [markdown]
# ## 9.º A - Alunos com classificação não inferior a 50 pontos

# %%
alunosA_pos = turma_A[turma_A["Pontos"] > 49]
display(alunosA_pos)
# Out:
#                               Nome  Pontos  Nível
# 9    ANA BENEDITA VINAGRE MAURÍCIO      85      4
# 15         ARIANA FERREIRA MACHADO      94      5
# 30     CAROLINA DOS SANTOS DELGADO      67      3
# 34    CECÍLIA BELO GALINHA HONÓRIO      63      3
# 36   CELINA PAULA MARTINS DOMINGOS      75      4
# 43        DINIS JOSÉ TOMÁS MOREIRA      86      4
# 44            DINIS LOURENÇO COSTA      88      4
# 48         FABIANA MARTINS VICENTE      88      4
# 54    GONÇALO FILIPE LUÍS TEIXEIRA      51      3
# 58          INÊS DE ALMEIDA SANTOS      51      3
# 59             INÊS AMÉRICO DUARTE      76      4
# 60      INÊS CRISTINA DIAS ROSÁRIO      57      3
# 65    IRÍS GERARDO CORREIA MORGADO      61      3
# 66         ÍRIS SOFIA DIAS ROSÁRIO      51      3
# 69             JACINTA SIMÕES BELO      88      4
# 77        JOSÉ MARIA LUÍS FERREIRA      99      5
# 80        LAVÍNIA FERREIRA MARQUES      67      3
# 93      MARGARIDA FIALHO HENRIQUES      78      4
# ...

# %% [markdown]
# ## 9.º A - Alunos com classificação inferior a 50 pontos

# %%
alunosA_neg = turma_A[turma_A["Pontos"] < 50]
display(alunosA_neg)
# Out:
#                                   Nome  Pontos  Nível
# 14   ANTHONY ISTANLLEY FERNANDES SOUZA       5      1
# 20               BEATRIZ TAVARES SILVA      29      2
# 92           MARCOS ROCHA ESTRELA PINA      27      2
# 116               MATILDE RAMALHO BELO      45      2
# 124       OLÍVIA SOFIA LOPES FORTUNATO      45      2

# %% [markdown]
# ## 9.º B

# %%
turma_B = tabela.loc[tabela["Turma"] == "B", ["Nome", "Pontos", "Nível"]]
display(turma_B)
# Out:
#                                 Nome  Pontos  Nível
# 2            AFONSO FERREIRA MACHADO      65      3
# 3            AFONSO FIGUEIREDO LOPES      30      2
# 6                AFONSO SIMÕES LOPES      46      2
# 22        BERNARDO EVANGELISTA SILVA      39      2
# 23                  BIA RUFINO DINIS      91      5
# 25            BRUNA CAETANO LOURENÇO      24      2
# 70               JOANA RIBEIRO PEDRO      66      3
# 72        JOÃO MIGUEL FERREIRA JORGE      56      3
# 76        JOSÉ CARLOS ALMEIDA MIGUEL      46      2
# 79               LAURA PENAS MARTINS      95      5
# 86          LOURENÇO FERREIRA SANTOS      65      3
# 88                 LUCAS LUÍS COELHO      35      2
# 109          MARTIM MARQUES EZEQUIEL      81      4
# 111           MARTINA QUITÉRIO SILVA      59      3
# 112           MATEUS MARQUES MACHADO      79      4
# 114           MATILDE FIRMINO COELHO      13      1
# 122               NINA FERREIRA PINA      71      4
# ...

# %% [markdown]
# ## Análise Estatística 9.º B

# %%
turma_B[["Pontos", "Nível"]].describe()
# Out:
#           Pontos      Nível
# count  26.000000  26.000000
# mean   50.846154   2.730769
# std    22.665732   1.002305
# min    13.000000   1.000000
# 25%    31.000000   2.000000
# 50%    51.000000   2.500000
# 75%    65.750000   3.000000
# max    95.000000   5.000000

# %% [markdown]
# ## 9.º B - Lista Ordenada por Pontos

# %%
turma_B.sort_values(by=['Pontos', 'Nível'], ascending=False).head(25)
# Out:
#                                 Nome  Pontos  Nível
# 79               LAURA PENAS MARTINS      95      5
# 23                  BIA RUFINO DINIS      91      5
# 109          MARTIM MARQUES EZEQUIEL      81      4
# 112           MATEUS MARQUES MACHADO      79      4
# 122               NINA FERREIRA PINA      71      4
# 70               JOANA RIBEIRO PEDRO      66      3
# 149           TOMÁS FERREIRA E SILVA      66      3
# 2            AFONSO FERREIRA MACHADO      65      3
# 86          LOURENÇO FERREIRA SANTOS      65      3
# 148           TOMÁS FERREIRA MORGADO      63      3
# 111           MARTINA QUITÉRIO SILVA      59      3
# 72        JOÃO MIGUEL FERREIRA JORGE      56      3
# 154                      VLAD BOLEAC      56      3
# 6                AFONSO SIMÕES LOPES      46      2
# 76        JOSÉ CARLOS ALMEIDA MIGUEL      46      2
# 145             TIAGO MARTINS MENDES      40      2
# 22        BERNARDO EVANGELISTA SILVA      39      2
# ...

# %% [markdown]
# ## 9.º B - Alunos com classificação não inferior a 50 pontos

# %%
alunosB_pos = turma_B[turma_B["Pontos"] > 49]
display(alunosB_pos)
# Out:
#                            Nome  Pontos  Nível
# 2       AFONSO FERREIRA MACHADO      65      3
# 23             BIA RUFINO DINIS      91      5
# 70          JOANA RIBEIRO PEDRO      66      3
# 72   JOÃO MIGUEL FERREIRA JORGE      56      3
# 79          LAURA PENAS MARTINS      95      5
# 86     LOURENÇO FERREIRA SANTOS      65      3
# 109     MARTIM MARQUES EZEQUIEL      81      4
# 111      MARTINA QUITÉRIO SILVA      59      3
# 112      MATEUS MARQUES MACHADO      79      4
# 122          NINA FERREIRA PINA      71      4
# 148      TOMÁS FERREIRA MORGADO      63      3
# 149      TOMÁS FERREIRA E SILVA      66      3
# 154                 VLAD BOLEAC      56      3

# %% [markdown]
# ## 9.º B - Alunos com classificação inferior a 50 pontos

# %%
alunosB_neg = turma_B[turma_B["Pontos"] < 50]
display(alunosB_neg)
# Out:
#                                 Nome  Pontos  Nível
# 3            AFONSO FIGUEIREDO LOPES      30      2
# 6                AFONSO SIMÕES LOPES      46      2
# 22        BERNARDO EVANGELISTA SILVA      39      2
# 25            BRUNA CAETANO LOURENÇO      24      2
# 76        JOSÉ CARLOS ALMEIDA MIGUEL      46      2
# 88                 LUCAS LUÍS COELHO      35      2
# 114           MATILDE FIRMINO COELHO      13      1
# 123                  NUNO LUÍS COITO      29      2
# 136               SIMÃO MARQUES PINA      22      2
# 137  SOFIA ALEXANDRA LOUREIRO MATEUS      29      2
# 142          THALITA SIRLEI DA SILVA      22      2
# 143   TIAGO ALEXANDRE DA SILVA LOPES      34      2
# 145             TIAGO MARTINS MENDES      40      2

# %% [markdown]
# ## Análise conjunta das turmas 9A e 9B

# %%
turma_AB = tabela.loc[(tabela["Turma"] == "A") | (tabela["Turma"] == "B")]
turma_AB[["Pontos", "Nível"]].describe()
# Out:
#           Pontos      Nível
# count  55.000000  55.000000
# mean   58.672727   3.054545
# std    23.471065   1.025927
# min     5.000000   1.000000
# 25%    42.500000   2.000000
# 50%    62.000000   3.000000
# 75%    77.500000   4.000000
# max    99.000000   5.000000
